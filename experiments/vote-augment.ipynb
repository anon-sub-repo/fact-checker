# %%
# Get Vote frame
import pandas as pd
import xml.etree.ElementTree as ET
import re

def get_vote_frame_info(vote_file):
    fn_prefix = '{http://framenet.icsi.berkeley.edu}'
    
    vote_root = ET.parse(vote_file).getroot()
    raw_def = vote_root.find(f'{fn_prefix}definition').text

    clean_def = raw_def.split('\n')[0].strip()
    clean_def = re.sub(r'<.*?>', '', clean_def).strip()

    vote_fe_nodes = vote_root.findall(f'{fn_prefix}FE')
    vote_fes = [(x.attrib['name'], x.find(f'{fn_prefix}definition').text) for x in vote_fe_nodes]
    clean_vote_fes = [(x[0], re.sub(r'<.*?>', '', x[1].split('\n')[0]).strip()) for x in vote_fes]

    # frame_info = {}
    # frame_info['Vote'] = {
    return {
        'definition': clean_def,
        'FEs': clean_vote_fes,
        'raw_definition': raw_def,
        'raw_FEs': vote_fes
    }
    
    # return frame_info

vote_frame_info = get_vote_frame_info('../data/fsp/Vote.xml')

# %%
tree = ET.parse('../data/fsp/FactChecks.xml')
root = tree.getroot()

# %%
fn_prefix = '{http://framenet.icsi.berkeley.edu}'
sent_nodes = root.findall(f'{fn_prefix}sentence')

vote_samples = []

for sent_node in sent_nodes[1:]:
    sent_text = sent_node.find(f'{fn_prefix}text').text
    # get annotations with status="MANUAL"
    sent_annotations = sent_node.findall(f'{fn_prefix}annotationSet[@status="MANUAL"]')
    
    for annotation in sent_annotations:
        # get the frame name
        frame_name = annotation.attrib['frameName']
        
        if frame_name != 'Vote':
            continue
        
        lu_name = annotation.attrib['luName']
        # get the target
        target = annotation.find(f'{fn_prefix}layer[@name="Target"]').find(f'{fn_prefix}label[@name="Target"]')
        start = int(target.attrib['start'])
        end = int(target.attrib['end'])+1
        target_text = sent_text[start:end]
        # get the frame elements
        frame_elements = annotation.findall(f'{fn_prefix}layer[@name="FE"]/{fn_prefix}label')
        fe_dict = {}
        for fe in frame_elements:
            fe_name = fe.attrib['name']
            fe_start = int(fe.attrib['start'])
            fe_end = int(fe.attrib['end'])+1
            fe_text = sent_text[fe_start:fe_end]
            fe_dict[fe_name] = {
                'text': fe_text,
                'start': fe_start,
                'end': fe_end
            }
        
        vote_samples.append((sent_text, frame_name, target_text, *[(fe_dict.get(fe, {}).get('start', -1), fe_dict.get(fe, {}).get('end', -1)) if fe in fe_dict else None for fe, _ in vote_frame_info['FEs']]))
        
        print(sent_text)
        print(frame_name)
        print(target_text)
        print(frame_elements)
# Out:
# Bernie Sanders was against the auto bailout and voted against the money that ended up saving the auto industry .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62858bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62858c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62858c70>]
# Bernie Sanders voted for the bill that gave special protection - immunity from liability - to the gun makers and sellers , limiting the Sandy Hook lawsuit .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6268d130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6268d180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6268d1d0>]
# He was the only Republican to vote against creating a House panel to investigate Planned Parenthood .
# Vote
# vote
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62574180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a625741d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62574220>]
# Ann Kirkpatrick votes with her party nearly 90 percent of the time .
# Vote
# votes
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62562ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62562ef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62562f40>]
# Bernie Sanders voted with Republicans to protect the Minutemen , a hate group that used military tactics against our community .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a624f9ae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a624f9b30>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a624f9b80>]
# After taking hundreds of thousands of dollars from Goldman Sachs and other Wall Street banks , Debbie Wasserman Schultz has voted to prevent the Consumer Financial Protection Bureau from regulating payday loans and addressing racial discrimination in car loans .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6238d0e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6238d130>]
# Debbie Wasserman Schultz voted repeatedly to send terminally ill patients to prison .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62397180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a623971d0>]
# Patrick Murphy is one of only three Democrats in the House today who voted to create the Benghazi committee .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a622d5220>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a622d5270>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a622d52c0>]
# Renee Ellmers was the only Republican to vote against an amendment to prioritize the deportation of sexual criminals who are illegal immigrants .
# Vote
# vote
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a621a0400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a621a0450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a621a04a0>]
# Sen. John McCain told dreamers that he 'll support the Dream Act , then he voted against it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62151e50>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62151ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a62151ef0>]
# Congressman Joe Heck has voted 62 percent of the time with Nancy Pelosi and the Democrats on a variety of important issues .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61fe9400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61fe9450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61fe94a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61fe94f0>]
# Ron Johnson voted to turn Medicare into a voucher program .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61ee6130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61ee6180>]
# Nevada lawmakers voted to allow teenaged boys to shower with your teenaged girls in public school locker rooms .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61e97a40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61e97a90>]
# Sen. Bennet votes with Obama 98 percent of the time .
# Vote
# votes
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61d64c70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61d64cc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61d64d10>]
# Hardly bipartisan
# Vote
# tisan
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61d6c400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61d6c450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61d6c4a0>]
# Did not vote for tax increases as a member of the West Miami City Commission .
# Vote
# vote
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61cebc20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61cebc70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61cebcc0>]
# British voters under 50 , especially millennials , overwhelmingly voted to stay , in the European Union .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c3d450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c3d4a0>]
# British voters under 50 , especially millennials , overwhelmingly voted to stay , in the European Union .
# Vote
# , esp
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c3d810>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c3d860>]
# British voters under 50 , especially millennials , overwhelmingly voted to stay , in the European Union .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c3dbd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c3dc20>]
# British voters under 50 , especially millennials , overwhelmingly voted to stay , in the European Union .
# Vote
# , esp
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c3df90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c46040>]
# It was older voters who voted to leave .
# Vote
#
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c468b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c46900>]
# It was older voters who voted to leave .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c46c70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c46cc0>]
# It was older voters who voted to leave .
# Vote
#
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c4f090>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c4f0e0>]
# It was older voters who voted to leave .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c4f450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61c4f4a0>]
# While serving in the city council , Rachel Zenzinger voted to use tax dollars to take a taxpayer-funded junket to China .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61aff6d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61aff720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61aff770>]
# Ron Johnson justifies his support of trade agreements by saying the U.S. has the Trade Adjustment Assistance program for displaced workers , but then he voted to eliminate it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61a9c3b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61a9c400>]
# Barack Obama voted for the very same language of Indiana 's Religious Freedom Restoration Act when he was in the Illinois state Senate .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61a2ad10>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61a2ad60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61a2adb0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61a2ae00>]
# Sexual orientation does n't have anything to do with this law .
# Vote
# ation
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a619b27c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a619b2810>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a619b2860>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a619b28b0>]
# As a U.S. senator , Russ Feingold voted against authorizing our military 11 separate times .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61508b80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61508bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61508c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61508c70>]
# Debbie Wasserman Schultz has voted for huge subsidies for the sugar industry as well as for delays in cleanups .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61491d60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a61491db0>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122f2c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122f310>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122f360>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122f6d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122f720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122f770>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122fae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122fb30>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122fea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122fef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6122ff40>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8310>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b83b0>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8770>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8ae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8b30>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8b80>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8ef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8f40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611b8f90>]
# Mike Pence voted against expanding the Children 's Health Insurance program , which Hillary helped to start .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611c0360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611c03b0>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611c0e00>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611c0e50>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611c0ea0>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cb270>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cb2c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cb310>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cb680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cb6d0>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cba40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cba90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cbae0>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cbe50>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cbea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611cbef0>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d32c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d3310>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d3680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d36d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d3720>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d3a90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d3ae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d3b30>]
# Mike Pence voted against requiring insurance companies to cover mental health and addiction treatment .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d3ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611d3ef0>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611db860>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611db8b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611db900>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611dbc70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611dbcc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611dbd10>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e50e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e5130>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e54a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e54f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e5540>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e58b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e5900>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e5950>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e5cc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611e5d10>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611ee0e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611ee130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611ee180>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611ee4f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611ee540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611ee590>]
# Mike Pence voted to end Medicare as we know it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611ee900>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a611ee950>]
# U.S. Sen. Johnny Isakson has voted for $ 7 trillion of our national debt !
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a610c34a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a610c34f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a610c3540>]
# Kim Myers voted repeatedly to raise taxes on the people of Broome County , but made millions off of tax savings when her family business relocated its headquarters .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60f421d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60f42220>]
# GOP Rep. Joe Heck of Nevada voted 23 times against banning terrorists from buying guns .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60e545e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60e54630>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60e54680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60e546d0>]
# Hillary Clinton voted to raise taxes on workers earning as little as $ 41,500 .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60db6270>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60db62c0>]
# U.S. Rep. Bruce Poliquin voted to force seniors to pay more for prescription drugs .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60df09f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60df0a40>]
# Tom Reed has actually voted for every single trade deal that has ever come before him in any form .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60cb1720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60cb1770>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60cb1810>]
# Joe Heck voted 10 times to defund Planned Parenthood and Heck opposes a woman 's right to choose , even when her health is at risk .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60c40180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60c401d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60c40220>]
# Ron Johnson voted five times for tax breaks that help companies ship Wisconsin jobs overseas .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60bb26d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60bb2720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60bb2770>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60bb27c0>]
# Marco Rubio voted against funding health clinics that provide critical care during this public health emergency Zika .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60bd3d60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60bd3db0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60bd3e00>]
# everybody just took then Senator Barack Obama at his word in 2008 when he said he would have voted against invading Iraq .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60b40310>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60b40360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60b403b0>]
# Patrick Murphy is the only candidate to have voted against every measure to fund Zika .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609f3b80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609f3bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609f3c20>]
# Russ Feingold was the only senator to vote against Homeland Security .
# Vote
# vote
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609d4040>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609d4090>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609d40e0>]
# Marco Rubio voted against every bill that would have helped keep our families safe .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609ee770>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609ee7c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609ee810>]
# Marco Rubio voted against every bill that would have helped keep our families safe .
# Vote
# bio v
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609eeb80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609eebd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609eec20>]
# Marco Rubio voted against every bill that would have helped keep our families safe .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609eef90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60977040>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60977090>]
# Marco Rubio voted against every bill that would have helped keep our families safe .
# Vote
# bio v
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60977400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60977450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609774a0>]
# He even voted against a bipartisan measure , introduced by a Republican , to prevent people on the no-fly list from purchasing guns .
# Vote
# d aga
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980220>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980270>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609802c0>]
# He even voted against a bipartisan measure , introduced by a Republican , to prevent people on the no-fly list from purchasing guns .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980630>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a609806d0>]
# He even voted against a bipartisan measure , introduced by a Republican , to prevent people on the no-fly list from purchasing guns .
# Vote
# d aga
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980a40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980a90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980ae0>]
# He even voted against a bipartisan measure , introduced by a Republican , to prevent people on the no-fly list from purchasing guns .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980e50>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60980ef0>]
# Marco Rubio voted to slash school funding by billions of dollars and would eliminate the Department of Education .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60899450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a608994a0>]
# Rob Portman even voted to allow people on the terrorism watch list to buy guns .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6086b180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6086b1d0>]
# Miami Congressman Carlos Curbelo supports drilling offshore and repeatedly voted against President Obama 's ability to fight pollution and combat climate change .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a607f3d10>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a607f3d60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a607f3db0>]
# She voted for a statewide fracking ban .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6064a810>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6064a860>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6064a8b0>]
# Rob Portman voted for the bipartisan bill to affirm climate change is real , humans significantly contribute to it and it needs to be addressed .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60454c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60454c70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60454cc0>]
# In Washington , D.C. , Sen. Richard Burr took millions from special interests , went there and cashed in , voted to cut his own taxes and raise taxes on working folks .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a603d94f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a603d9540>]
# Colorado congressional candidate Morgan Carroll voted to allow welfare recipients to use your tax dollars at ATMs at strip clubs and pot dispensaries .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60346680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a603466d0>]
# Secret documents reveal that Iran could obtain a nuclear weapon far sooner than we were told .
# Vote
# eal t
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a603285e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60328630>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60328680>]
# And Tammy Duckworth voted yes on the Iran nuclear deal .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a602b1360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a602b13b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a602b1400>]
# Sen. Johnny Isakson voted for a trade agreement , with China costing Georgia 93,000 jobs .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60258900>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60258950>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a602589a0>]
# Sen. Richard Burr voted no on the Violence Against Women Act .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6014a090>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6014a0e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6014a130>]
# During his 18-year Senate career , Russ Feingold supported judges who voted to deny your individual Second Amendment right .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a601049f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60104a40>]
# He promises to protect those rights , but that 's not what his record shows .
# Vote
# shows
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6010c950>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6010c9a0>]
# When Rachel Zenzinger was on the Arvada City Council , she voted to spend taxpayer funds for a junket to China .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60115a90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a60115ae0>]
# Joe Heck voted to shut down the government .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6005a220>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a6005a270>]
# Democratic U.S. Senate candidate Russ Feingold voted over 250 times to raise taxes .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ff15090>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ff150e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ff15130>]
# Jack Berry voted for a plan to cut $ 23.8 million from our schools .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fe3c310>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fe3c360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fe3c3b0>]
# Chris Koster opposed protecting the women of Missouri because he was one of only four senators to vote against a bill ending the practice of making rape victims pay for their own rape kits .
# Vote
# vote
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fdc15e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fdc1630>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fdc1680>]
# Russ Feingold voted to raise taxes on Social Security benefits for seniors , he even tried to give Social Security benefits to illegal immigrants .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fd8b450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fd8b400>]
# Donald Trump and Ron Johnson oppose a woman 's right to choose and Johnson voted against the Violence Against Women Act .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fd94130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fd94180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fd941d0>]
# Richard Burr voted to protect tax breaks for companies that ship jobs overseas but voted against a tax break to help working people .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fda6400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fda6450>]
# Richard Burr voted to protect tax breaks for companies that ship jobs overseas but voted against a tax break to help working people .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fda67c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fda6810>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fda6860>]
# Richard Burr voted to protect tax breaks for companies that ship jobs overseas but voted against a tax break to help working people .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fda6bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fda6c20>]
# Richard Burr voted to protect tax breaks for companies that ship jobs overseas but voted against a tax break to help working people .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fda6f90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fdae040>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fdae090>]
# Russ Feingold voted to raise taxes on Social Security benefits for seniors , he even tried to give Social Security benefits to illegal immigrants .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fd36c70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fd36cc0>]
# Roy Blunt voted to raise his own pay 12 times while in Congress .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fce6ef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fce6f40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fce6f90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fcef040>]
# Democrat Stephen Webber voted to allow sex offenders to be within 500 feet of childcare centers and playgrounds , and even voted to allow sex offenders to be coaches .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fceff40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fceff90>]
# Democrat Stephen Webber voted to allow sex offenders to be within 500 feet of childcare centers and playgrounds , and even voted to allow sex offenders to be coaches .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fc78360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fc783b0>]
# Democrat Stephen Webber voted to allow sex offenders to be within 500 feet of childcare centers and playgrounds , and even voted to allow sex offenders to be coaches .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fc78720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fc78770>]
# Democrat Stephen Webber voted to allow sex offenders to be within 500 feet of childcare centers and playgrounds , and even voted to allow sex offenders to be coaches .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fc78ae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5fc78b30>]
# For the tens of millions of Americans who will lose their health care if the ACA is repealed , I vote no .
# Vote
# vote
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f776540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f776590>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f7765e0>]
# # MakeAmericaSickAgain
# Vote
#
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f77c130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f77c180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f77c1d0>]
# Thirteen Democratic senators voted against cheaper medicines and took millions from big pharma since 2011 .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f742cc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f742d10>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5f742d60>]
# 215 members of Congress just voted to let your ISP spy on what type of underwear you buy and sell that data to advertisers .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5eb8edb0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5eb8ee00>]
# Judge Neil Gorsuch 's record on the 10th U.S . Circuit Court of Appeals falls well within the mainstream , because he 's voted with a majority 99 percent of the time and roughly 97 percent of the cases he has participated in were decided unanimously .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ea42bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ea42c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ea42c70>]
# They voted for a border wall in 2006 .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5fcb30>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5fcb80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5fcbd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5fcc20>]
# They voted for a border wall in 2006 .
# Vote
# rder
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5fcf90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604040>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604090>]
# They voted for a border wall in 2006 .
# Vote
# r a b
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6044a0>]
# They voted for a border wall in 2006 .
# Vote
# r a b
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604810>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604860>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6048b0>]
# They voted for a border wall in 2006 .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604c70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604cc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e604d10>]
# They voted for a border wall in 2006 .
# Vote
# rder
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e0e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e180>]
# They voted for a border wall in 2006 .
# Vote
# r a b
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e4f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e590>]
# They voted for a border wall in 2006 .
# Vote
# r a b
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e900>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e950>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60e9a0>]
# They voted for a border wall in 2006 .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60ed10>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60ed60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60edb0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e60ee00>]
# They voted for a border wall in 2006 .
# Vote
# rder
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6161d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616220>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616270>]
# They voted for a border wall in 2006 .
# Vote
# r a b
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6165e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616630>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616680>]
# They voted for a border wall in 2006 .
# Vote
# r a b
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6169f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616a40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616a90>]
# They voted for a border wall in 2006 .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616e00>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616e50>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e616ef0>]
# They voted for a border wall in 2006 .
# Vote
# rder
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6202c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e620310>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e620360>]
# They voted for a border wall in 2006 .
# Vote
# r a b
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6206d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e620720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e620770>]
# They voted for a border wall in 2006 .
# Vote
# r a b
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e620ae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e620b80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e620b30>]
# Then-Senator Obama voted for it .
# Vote
# Senat
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e628360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6283b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e628400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e628450>]
# Then-Senator Obama voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e6287c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e628810>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e628860>]
# Then-Senator Obama voted for it .
# Vote
# Obama
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e628bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e628c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e628c70>]
# Then-Senator Obama voted for it .
# Vote
# Obama
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1040>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1090>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b10e0>]
# Then-Senator Obama voted for it .
# Vote
# Senat
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b14a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b14f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1540>]
# Then-Senator Obama voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b18b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1900>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1950>]
# Then-Senator Obama voted for it .
# Vote
# Obama
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1cc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1d10>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5b1d60>]
# Then-Senator Obama voted for it .
# Vote
# Obama
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb1d0>]
# Then-Senator Obama voted for it .
# Vote
# Senat
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb590>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb5e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb630>]
# Then-Senator Obama voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb9a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bb9f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bba40>]
# Then-Senator Obama voted for it .
# Vote
# Obama
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bbdb0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bbe00>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5bbe50>]
# Then-Senator Obama voted for it .
# Vote
# Obama
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4220>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4270>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c42c0>]
# Then-Senator Obama voted for it .
# Vote
# Senat
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4630>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c46d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4720>]
# Then-Senator Obama voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4a90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4ae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4b30>]
# Then-Senator Obama voted for it .
# Vote
# Obama
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4ef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5c4f40>]
# Then-Senator Obama voted for it .
# Vote
# Obama
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5cc310>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5cc360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5cc3b0>]
# Sen. Schumer voted for it .
# Vote
# Schum
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ccb80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ccbd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ccc20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ccc70>]
# Sen. Schumer voted for it .
# Vote
# for i
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4040>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4090>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d40e0>]
# Sen. Schumer voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d44a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d44f0>]
# Sen. Schumer voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4860>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d48b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4900>]
# Sen. Schumer voted for it .
# Vote
# Schum
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4c70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4cc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4d10>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5d4d60>]
# Sen. Schumer voted for it .
# Vote
# for i
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de1d0>]
# Sen. Schumer voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de590>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de5e0>]
# Sen. Schumer voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de950>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de9a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5de9f0>]
# Sen. Schumer voted for it .
# Vote
# Schum
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ded60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5dedb0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5dee00>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5dee50>]
# Sen. Schumer voted for it .
# Vote
# for i
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7220>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7270>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e72c0>]
# Sen. Schumer voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7630>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e76d0>]
# Sen. Schumer voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7a40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7a90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7ae0>]
# Sen. Schumer voted for it .
# Vote
# Schum
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7e50>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7ef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5e7f40>]
# Sen. Schumer voted for it .
# Vote
# for i
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ef310>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ef360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ef3b0>]
# Sen. Schumer voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ef720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ef770>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5ef7c0>]
# Sen. Schumer voted for it .
# Vote
# voted
# ...
# Sen. Clinton voted for it .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e59d3b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e59d400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e59d450>]
# We do n't understand why the Democrats are so wholeheartedly against President Trump 's border wall .
# Vote
#  n't
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e522540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e522590>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e5225e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e522630>]
# They voted for it in 2006 .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e522e50>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e522ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e522ef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e522f40>]
# On voting for a health care bill without an up-to-date Congressional Budget Office score .
# Vote
# voting
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e4284f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e428540>]
# U.S. Rep. Carlos Curbelo voted for a health care bill that will let insurance companies charge five times more for people over 50 .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e2eaef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e2eaf40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5e2eaf90>]
# Elizabeth Warren does n't think Obamacare goes far enough :
# Vote
#  Obam
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da20270>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da202c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da20310>]
# The next step is single payer .
# Vote
#
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da20b30>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da20b80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da20bd0>]
# Does Sen. Nelson agree ?
# Vote
#
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da283b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da28400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da28450>]
# He has in the past Sen. Nelson votes with Warren 90 percent of the time .
# Vote
# votes
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da28ef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da28f40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5da28f90>]
# Barack Obama , Chuck Schumer and Hillary Clinton all voted for a border wall as senators .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5d21a360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5d21a3b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5d21a400>]
# Just to give you an idea of how far away America is from actual gun control , this week Congress is going to vote on deregulating gun silencers .
# Vote
# vote
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5cc77680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5cc776d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5cc77720>]
# Because I guess Congress is thinking gun violence is out of control : 'How can we make it quieter ? '
# Vote
#
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5cc7ff40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5cc7ff90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5cc87040>]
# Stacey Evans voted for school vouchers in the beginning .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ca62e50>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ca62ea0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ca62ef0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ca62f40>]
# Tammy Baldwin voted for $ 5 trillion in higher taxes .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c78f090>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c78f0e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c78f130>]
# Inviting violent criminals to carry concealed weapons does n't save lives .
# Vote
# ls to
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c29e360>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c29e3b0>]
# Inviting domestic abusers to carry concealed weapons does n't save lives .
# Vote
# s to
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c29ed10>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c29ed60>]
# Inviting convicted stalkers to carry concealed weapons does n't save lives .
# Vote
# ers t
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c2a6720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c2a6770>]
# Yet the @ HouseGOP just voted to do exactly that .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c2af0e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c2af130>]
# Democratic lawmakers who voted in favor of short-term spending bills just voted to deport Dreamers .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c072900>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c072950>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c0729a0>]
# Democratic lawmakers who voted in favor of short-term spending bills just voted to deport Dreamers .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c072d10>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c072d60>]
# Democratic lawmakers who voted in favor of short-term spending bills just voted to deport Dreamers .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c07a130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c07a180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c07a1d0>]
# Democratic lawmakers who voted in favor of short-term spending bills just voted to deport Dreamers .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c07a540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5c07a590>]
# Heitkamp has voted against Trump 68 percent of time .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5bc39ae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5bc39b30>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5bc39b80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5bc39bd0>]
# In 2005 or 2006 U.S. Sen. Chuck Schumer voted for the wall .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5bc1ca90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5bc1cae0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5bc1cb30>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5bc1cb80>]
# In the Senate , Mike DeWine voted with Hillary Clinton to let illegal immigrants receive Social Security .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b725c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b725c70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b725cc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b725d10>]
# And in Ohio , DeWine allowed illegal immigrants to receive driver 's licenses .
# Vote
#  ille
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b72f770>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b72f7c0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b72f810>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b72f860>]
# Congresswoman Martha McSally voted to let companies sell your internet data to the highest bidder without your consent .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b4ffcc0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b4ffd10>]
# Then she got paid $ 42,000 by the very corporations she allowed to sell your personal info .
# Vote
#  the
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b5088b0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b508900>]
# Republican Rep. Todd Rokita of Indiana voted against Trump 's border wall .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b461f40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b461f90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b469040>]
# I am the only one onstage who has never voted to raise your taxes .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b2dbc20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b2dbc70>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b2dbcc0>]
# These two , each , a billion dollars worth of votes to raise your taxes .
# Vote
# th of
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b2ec4a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b2ec4f0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b2ec540>]
# Mitch McConnell was one of the few senators that voted after Tiananmen Square not to have punitive actions against China for human rights violations .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b270b80>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b270bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b270c20>]
# Bill Nelson voted against requiring Iran to recognize Israel and release American hostages .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b1fad60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b1fadb0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b1fae00>]
# Luke Messer and Todd Rokita voted to fast-track Obama 's trade deals .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b203810>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b203860>]
# Dean Heller has voted for a GOP bill that funded efforts to revive Yucca Mountain .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b0a2400>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b0a2450>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b0a24a0>]
# Gwen Graham voted against President Obama 52 percent of the time .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b024180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b0241d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b024220>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5b024270>]
# Jim Renacci has been a lobbyist even while in Congress and voted to make it easier for lobbyists to hold key government positions and harder to investigate conflicts of interest .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ad2a9a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ad2a9f0>]
# Rep. Dan Donovan voted for Tax Cuts .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ac71a40>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ac71a90>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ac71ae0>]
# Marsha Blackburn voted against military pay raise .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ac9dd60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ac9ddb0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5ac9de00>]
# Sherrod Brown in 1978 voted for stricter removal standards for voter registration and then enforced them as Secretary of State .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a9a0680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a9a06d0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a9a0720>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a9a0770>]
# Ron DeSantis voted in an agricultural bill to give food stamps to illegal immigrants .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a9529a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a9529f0>]
# Sen. Bill Nelson voted for higher taxes 349 times .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a88c540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a88c590>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a88c5e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a88c630>]
# Claire McCaskill voted for 100 percent of President Obama 's judicial nominees .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a776950>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a7769a0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a7769f0>]
# President Trump proposed the increase to $ 700 billion to our military budget , which included the 355-ship Navy , which included a military pay increase , a modest one , which included , a yet even more modest housing allowance , but yet Sen. Tim Kaine even voted against giving more money to our men and women who are in the military service and against our housing allowance .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a4f5bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a4f5c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a4f5c70>]
# Sherrod Brown votes 97 percent with Chuck Schumer , almost 95 plus percent with Elizabeth Warren .
# Vote
# votes
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a48c090>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a48c0e0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a48c130>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a48c180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a48c1d0>]
# I 've always voted for keeping the government open .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a3c9bd0>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a3c9c20>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a3c9c70>]
# I 've never cast a vote to shut down the government .
# Vote
# ast a
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a3d4630>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a3d4680>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a3d46d0>]
# Congressman DeSantis voted to cut Social Security and Medicare and voted to increase the retirement age .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a2dbd60>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a2dbdb0>]
# Congressman DeSantis voted to cut Social Security and Medicare and voted to increase the retirement age .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a2e4180>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a2e41d0>]
# Congressman DeSantis voted to cut Social Security and Medicare and voted to increase the retirement age .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a2e4540>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a2e4590>]
# Congressman DeSantis voted to cut Social Security and Medicare and voted to increase the retirement age .
# Vote
# voted
# [<Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a2e4900>, <Element '{http://framenet.icsi.berkeley.edu}label' at 0x7f4a5a2e4950>]

# %%
vote_samples_df = pd.DataFrame(vote_samples, columns=['sentence', 'frame', 'target', *[fe for fe, _ in vote_frame_info['FEs']]])
vote_samples_df = vote_samples_df[vote_samples_df.target.apply(lambda x: x.lower() in {'vote', 'voted', 'votes'})]
vote_samples_df = vote_samples_df.drop_duplicates()

# %%
# Get all permutations of the frame elements
from itertools import permutations

vote_prompts = []

vote_fes = [fe for fe, _ in vote_frame_info['FEs']]

vote_permutations = []

for i, sample in vote_samples_df.iterrows():
    present_fes = sample[vote_fes][sample[vote_fes].notnull()]
    skip = False
    
    fe_str = '\n- '.join([f'{fe}: {sample.sentence[fe_span[0]:fe_span[1]]}' for fe, fe_span in present_fes.sort_values().items()])
    
    for perm in permutations(present_fes.items()):
        prev_start = -1
        for _, fe_span in perm:
            if fe_span[0] < prev_start:
                skip = False
                break
            prev_start = fe_span[0]
            skip = True
            
        if skip:
            skip = False
            continue
        
        prompt = f'Frame: Vote\n\nSentence: {sample.sentence}\n\nFrame Elements:\n- {fe_str}\n\n' \
                 f'New order of frame elements: {", ".join([fe_name for fe_name, _ in perm])}\n\n'
                #  f'This sentence presents the frame elements above in the order they appear in the sentence. ' \
                #  f'Your task is to create a new high quality sentence which retains the same meaning and uses all of the same frame elements such that the order of the frame elements are in the order of: {", ".join([fe_name for fe_name, _ in perm])}.'
        vote_prompts.append(prompt)

        vote_permutations.append((*sample.values.tolist(), prompt))

# %%
frame_definitions = 'test definition.'
sentence = 'this is a claim'

prompt = f"Frames and their elements:\n{frame_definitions}\n\nAnnotate the following sentence:\n\"{sentence}\"\n\nFormat the response as follows:\n\nFormat: Annotated Sentence:\nFrame: Occupy_rank\nElements: Dimension, Item, Rank, Comparison_set, Time\n\nAnalysis:\n- Dimension: [Dimension]\n- Item 1: [Item 1]\n- Rank 1: [Rank 1]\n- Item 2: [Item 2]\n- Rank 2: [Rank 2]\n- Comparison set: [Comparison_set]\n- Time: [Time]\n\nAnnotation:\n\"[Sentence]\""

print(prompt)
# Out:
# Frames and their elements:
# test definition.
#
# Annotate the following sentence:
# "this is a claim"
#
# Format the response as follows:
#
# Format: Annotated Sentence:
# Frame: Occupy_rank
# Elements: Dimension, Item, Rank, Comparison_set, Time
#
# Analysis:
# - Dimension: [Dimension]
# - Item 1: [Item 1]
# - Rank 1: [Rank 1]
# - Item 2: [Item 2]
# - Rank 2: [Rank 2]
# - Comparison set: [Comparison_set]
# - Time: [Time]
#
# Annotation:
# "[Sentence]"

# %%
# from openai import OpenAI

# client = OpenAI()

# gpt_outputs = []

# for prompt in vote_prompts:
#     completion = client.chat.completions.create(
#         model="gpt-3.5-turbo",
#         messages=[
#             {"role": "system", "content": "You are a bot helping a user create a new high quality sentence with the same meaning as the original sentence. The original sentence presents the frame elements in a specific order. Your task is to create a new sentence that retains the same meaning using a different order of the frame elements provided by the user. The output shall not modify the frame elements."},
#             {"role": "user", "content": prompt},
#         ]
#     )
    
#     gpt_outputs.append((prompt, completion.choices[0].message.content))

#     # Save outputs to a file every 10 prompts
#     if len(gpt_outputs) % 10 == 0:
#         with open('../data/fsp/vote_order_augment.txt', 'w') as f:
#             for prompt, output in gpt_outputs:
#                 f.write(f'#@Prompt:\n{prompt}\n\n#@Output:\n{output}\n\n\n\n')

# %%
# gpt_outputs_df = pd.DataFrame(gpt_outputs, columns=['prompt', 'output'])
# gpt_outputs_df.to_csv('../data/fsp/vote_order_augment.csv', index=False)

gpt_outputs_df = pd.read_csv('../data/fsp/vote_order_augment.csv')

new_vote_samples_df = pd.DataFrame(vote_permutations, columns=['og_sentence', 'frame', 'target', *[f'og_{x}' for x in vote_fes], 'prompt'])

# right side should be new_
print(gpt_outputs_df.shape, new_vote_samples_df.shape)

new_vote_samples_df['new_sentence'] = gpt_outputs_df.output
# Out:
# (675, 2) (675, 12)

# %%
new_vote_samples_df.head(1)
# Out:
#                                          og_sentence frame target og_Agent  \
# 0  Bernie Sanders was against the auto bailout an...  Vote  voted  (0, 14)
#
#     og_Issue og_Side og_Position og_Frequency og_Time og_Place  \
# 0  (62, 110)    None    (54, 61)         None    None     None
#
#   og_Support_rate                                             prompt  \
# 0            None  Frame: Vote\n\nSentence: Bernie Sanders was ag...
#
#                                         new_sentence
# 0  Bernie Sanders voted against the money that en...

# %%
valid_new_samples = new_vote_samples_df[new_vote_samples_df.apply(lambda x: all([x.og_sentence[x[f'og_{fe}'][0]:x[f'og_{fe}'][1]].lower() in x.new_sentence.lower() 
                                                                                 if x[f'og_{fe}'] is not None else True for fe in vote_fes]), axis=1)].copy()

for fe in vote_fes:
    valid_new_samples[f'new_{fe}'] = valid_new_samples.apply(lambda x: (x.new_sentence.lower().index(x.og_sentence[x[f'og_{fe}'][0]:x[f'og_{fe}'][1]].lower()), 
                                                                        x.new_sentence.lower().index(x.og_sentence[x[f'og_{fe}'][0]:x[f'og_{fe}'][1]].lower())+len(x.og_sentence[x[f'og_{fe}'][0]:x[f'og_{fe}'][1]])) 
                                                             if x[f'og_{fe}'] is not None else None, axis=1)

# %%
augmented_samples = valid_new_samples[['og_sentence', 'new_sentence', *[f'new_{fe}' for fe in vote_fes]]].copy()
augmented_samples.rename(columns={x:x[4:] for x in augmented_samples.keys() if 'og_' not in x}, inplace=True)
augmented_samples
# Out:
#                                            og_sentence  \
# 0    Bernie Sanders was against the auto bailout an...
# 1    Bernie Sanders was against the auto bailout an...
# 2    Bernie Sanders was against the auto bailout an...
# 3    Bernie Sanders was against the auto bailout an...
# 4    Bernie Sanders was against the auto bailout an...
# ..                                                 ...
# 670  I 've always voted for keeping the government ...
# 671  I 've always voted for keeping the government ...
# 672  I 've always voted for keeping the government ...
# 673  Congressman DeSantis voted to cut Social Secur...
# 674  Congressman DeSantis voted to cut Social Secur...
#
#                                               sentence     Agent     Issue  \
# 0    Bernie Sanders voted against the money that en...   (0, 14)  (29, 77)
# 1    The money that ended up saving the auto indust...  (70, 84)   (0, 48)
# 2    The money that ended up saving the auto indust...  (58, 72)   (0, 48)
# 3    Against the money that ended up saving the aut...  (58, 72)   (8, 56)
# 4    Against the money that ended up saving the aut...  (58, 72)   (8, 56)
# ..                                                 ...       ...       ...
# 670  Keeping the government open is the issue I've ...    (4, 5)   (0, 27)
# 671  For keeping the government open, I 've always ...    (8, 9)   (4, 31)
# 672  For keeping the government open, I've always v...    (8, 9)   (4, 31)
# 673  To cut Social Security and Medicare, Congressm...  (37, 57)   (0, 35)
# 674  To increase the retirement age, Congressman De...  (32, 52)   (0, 30)
#
#      Side  Position Frequency  Time Place Support_rate
# 0    None  (21, 28)      None  None  None         None
# 1    None  (59, 66)      None  None  None         None
# 2    None  (77, 84)      None  None  None         None
# 3    None    (0, 7)      None  None  None         None
# 4    None    (0, 7)      None  None  None         None
# ..    ...       ...       ...   ...   ...          ...
# 670  None  (59, 62)      None  None  None         None
# 671  None    (0, 3)      None  None  None         None
# 672  None    (0, 3)      None  None  None         None
# 673  None      None      None  None  None         None
# 674  None      None      None  None  None         None
#
# [538 rows x 10 columns]

# %%
vote_re = re.compile(r'\bvot(ed|es|e|ing){1}\b', re.IGNORECASE)

# Count number of times the word "vote" appears in the new sentence
# augmented_samples.sentence.apply(lambda x: len([x.span() for x in vote_re.finditer(x)]) == 1).sum()
augmented_samples['target_span'] = augmented_samples.sentence.apply(lambda x: [x.span() for x in vote_re.finditer(x)][0])

# %%
# augmented_samples.to_csv('data/fe_order_permutation_samples.csv', index=False)

# %%
# Compare old permutation counts to new ones.

# Get old permutation counts:
print('Old permutation counts:')
print(vote_samples_df.apply(lambda x: [z[0] for z in sorted([(fe, x[fe]) for fe in vote_fes if x[fe] is not None], key=lambda y: y[-1])], axis=1).value_counts().head(25))

# Get new permutation counts:
print('\n\nNew permutation counts:')
print(augmented_samples.drop_duplicates().apply(lambda x: [z[0] for z in sorted([(fe, x[fe]) for fe in vote_fes if x[fe] is not None], key=lambda y: y[-1])], axis=1).value_counts().head(25))

# Merge old and new
print('\n\nMerged permutation counts:')
print(pd.concat([vote_samples_df, augmented_samples]).drop_duplicates().apply(lambda x: [z[0] for z in sorted([(fe, x[fe]) for fe in vote_fes if x[fe] is not None], key=lambda y: y[-1])], axis=1).value_counts().head(25))


# TODO: New prompt which can handle changed FEs, e.g., ask GPT to do something like: 
# (she) vote (against) (raising the minimum wage) -> On the vote to (raise the minimum wage), (she) cast a vote (against) it
# Could then either do edit distance to match the spans, or have it directly output the span, e.g., [Issue](raise the minimum wage)
# Out:
# Old permutation counts:
# [Agent, Position, Issue]                 45
# [Agent, Issue]                           35
# [Agent, Position, Issue, Time]            4
# [Agent, Side, Support_rate]               4
# [Agent, Frequency, Issue]                 3
# [Agent, Position, Side, Support_rate]     2
# [Agent, Position, Issue, Frequency]       2
# [Agent, Frequency, Position, Issue]       2
# [Time, Agent, Issue]                      2
# [Position, Issue, Agent]                  1
# [Agent, Support_rate, Side, Issue]        1
# [Agent, Issue, Frequency, Time]           1
# [Issue, Agent, Position]                  1
# [Agent, Side, Issue]                      1
# [Time, Agent, Position, Issue]            1
# [Place, Agent, Side, Issue]               1
# [Agent, Time, Issue]                      1
# [Agent, Time, Position, Issue]            1
# [Agent, Support_rate, Side]               1
# Name: count, dtype: int64
#
#
# New permutation counts:
# [Position, Issue, Agent]               36
# [Issue, Agent]                         32
# [Issue, Position, Agent]               26
# [Agent, Position, Issue]               25
# [Issue, Agent, Position]               15
# [Agent, Issue, Position]               15
# [Issue, Position, Agent, Time]          8
# [Frequency, Agent, Position, Issue]     7
# [Support_rate, Agent, Side]             6
# [Time, Agent, Position, Issue]          6
# [Frequency, Position, Issue, Agent]     5
# [Side, Agent, Support_rate]             5
# [Time, Position, Issue, Agent]          5
# [Position, Issue, Time, Agent]          5
# [Position, Issue, Frequency, Agent]     5
# [Issue, Position, Frequency, Agent]     4
# [Support_rate, Side, Agent]             4
# [Agent, Position, Issue, Frequency]     4
# [Issue, Agent, Frequency]               4
# [Side, Support_rate, Agent]             4
# [Position, Issue, Agent, Frequency]     4
# [Issue, Agent, Time]                    3
# [Agent, Side, Support_rate]             3
# [Issue, Frequency, Agent, Position]     3
# [Frequency, Agent, Issue]               3
# Name: count, dtype: int64
#
#
# Merged permutation counts:
# [Agent, Position, Issue]               70
# [Position, Issue, Agent]               37
# [Agent, Issue]                         35
# [Issue, Agent]                         32
# [Issue, Position, Agent]               26
# [Issue, Agent, Position]               16
# [Agent, Issue, Position]               15
# [Issue, Position, Agent, Time]          8
# [Frequency, Agent, Position, Issue]     7
# [Time, Agent, Position, Issue]          7
# [Agent, Side, Support_rate]             7
# [Agent, Position, Issue, Time]          6
# [Agent, Position, Issue, Frequency]     6
# [Support_rate, Agent, Side]             6
# [Agent, Frequency, Position, Issue]     5
# [Time, Position, Issue, Agent]          5
# [Position, Issue, Frequency, Agent]     5
# [Side, Agent, Support_rate]             5
# [Position, Issue, Time, Agent]          5
# [Frequency, Position, Issue, Agent]     5
# [Issue, Agent, Frequency]               4
# [Issue, Position, Frequency, Agent]     4
# [Position, Issue, Agent, Frequency]     4
# [Time, Agent, Issue]                    4
# [Support_rate, Side, Agent]             4
# Name: count, dtype: int64

# %%
augmented_samples.drop_duplicates().sentence.values
